# %%
from matplotlib import pyplot as mp

# %%
x = [0.017952, 0.042576, 0.09744 , 0.18888 , 0.258]

# %%
fedavg = [148.581, 133.983, 125.556, 123.917, 123.69]
maxnetBeta60 = [147.223, 133.085, 127.115, 125.135, 122.535]

# %%
mp.plot(x, fedavg, label="fedavg")
mp.plot(x, maxnetBeta60, label="maxnet60")
mp.legend()

# %%
x = [0.017952, 0.042576, 0.09744, 0.258]
fedavg = [148.581, 133.983, 125.556, 123.69]
maxnetBeta60 = [147.223, 133.085, 127.115, 122.535]
mp.plot(x, fedavg, label="fedavg")
mp.plot(x, maxnetBeta60, label="maxnet60")
mp.legend()

# %%
x = [0.017952, 0.042576, 0.09744, 0.258]
x2 = [0.017952, 0.042576, 0.09744 , 0.18888 , 0.258]
fedavg = [148.581, 133.983, 125.556, 123.69]
maxnetBeta60 = [147.223, 133.085, 127.115, 125.135, 122.535]
mp.plot(x, fedavg, label="fedavg")
mp.plot(x2, maxnetBeta60, label="maxnet60")
mp.legend()

# %%
import csv
import matplotlib
matplotlib.rcParams['font.family'] = "Times New Roman"

def_font_size = 16

matplotlib.rcParams['font.size'] = def_font_size=16
