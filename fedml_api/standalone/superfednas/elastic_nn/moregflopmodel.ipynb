# %%
from darts import genotypes
from darts.model import NetworkCIFAR
genotype = genotypes.FedNAS_V1
print(genotype)
model = NetworkCIFAR(320, 10, 4, False, genotype)

# %%
total_params = sum(p.numel() for p in model.parameters())
print(total_params)

# %%
from fvcore.nn import FlopCountAnalysis
import torch
flops = FlopCountAnalysis(model, (torch.zeros((64, 3, 32, 32))))

# %%
print(flops.total())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1g/k9xfmv_s29vf0f5bf06smtn00000gn/T/ipykernel_79693/2891716673.py in <module>
# ----> 1 print(flops.total())
#
# /opt/anaconda3/lib/python3.9/site-packages/fvcore/nn/jit_analysis.py in total(self, module_name)
#     246             int : The aggregated statistic.
#     247         """
# --> 248         stats = self._analyze()
#     249         module_name = self.canonical_module_name(module_name)
#     250         total_count = sum(stats.counts[module_name].values())
#
# /opt/anaconda3/lib/python3.9/site-packages/fvcore/nn/jit_analysis.py in _analyze(self)
#     549             elif self._warn_trace == "no_tracer_warning":
#     550                 warnings.filterwarnings("ignore", category=TracerWarning)
# --> 551             graph = _get_scoped_trace_graph(self._model, self._inputs, self._aliases)
#     552
# ...

# %%
print(model)
# Out:
# NetworkCIFAR(
#   (stem): Sequential(
#     (0): Conv2d(3, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (cells): ModuleList(
#     (0): Cell(
#       (preprocess0): ReLUConvBN(
#         (op): Sequential(
#           (0): ReLU()
#           (1): Conv2d(48, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (preprocess1): ReLUConvBN(
#         (op): Sequential(
#           (0): ReLU()
#           (1): Conv2d(48, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (_ops): ModuleList(
#         (0): SepConv(
#           (op): Sequential(
#             (0): ReLU()
# ...

# %%
from fvcore.nn import FlopCountAnalysis
flops = FlopCountAnalysis(model, input)
print(flops.total())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/1g/k9xfmv_s29vf0f5bf06smtn00000gn/T/ipykernel_79693/290340283.py in <module>
#       1 from fvcore.nn import FlopCountAnalysis
#       2 flops = FlopCountAnalysis(model, input)
# ----> 3 print(flops.total())
#
# /opt/anaconda3/lib/python3.9/site-packages/fvcore/nn/jit_analysis.py in total(self, module_name)
#     246             int : The aggregated statistic.
#     247         """
# --> 248         stats = self._analyze()
#     249         module_name = self.canonical_module_name(module_name)
#     250         total_count = sum(stats.counts[module_name].values())
#
# /opt/anaconda3/lib/python3.9/site-packages/fvcore/nn/jit_analysis.py in _analyze(self)
#     549             elif self._warn_trace == "no_tracer_warning":
#     550                 warnings.filterwarnings("ignore", category=TracerWarning)
# ...
